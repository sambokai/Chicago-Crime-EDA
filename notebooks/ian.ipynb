# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

current_dir = os.getcwd()

print("Daten werden eingelesen...")
data = pd.read_csv(f"{current_dir}/../data/crimes.csv")
print("Daten erfolgreich geladen.")
# Out:
# Daten werden eingelesen...
# Daten erfolgreich geladen.

# %%
data.columns.format()
# Out:
# ['ID',
#  'Case Number',
#  'Date',
#  'Block',
#  'IUCR',
#  'Primary Type',
#  'Description',
#  'Location Description',
#  'Arrest',
#  'Domestic',
#  'Beat',
#  'District',
#  'Ward',
#  'Community Area',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Updated On',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
pd.DataFrame(data.groupby('Primary Type').size().sort_values(ascending=False).rename('Count').reset_index())
# Out:
#                          Primary Type  Count
# 0                               THEFT  55371
# 1                             BATTERY  43319
# 2                     CRIMINAL DAMAGE  24102
# 3                             ASSAULT  17663
# 4                  DECEPTIVE PRACTICE  15377
# 5                       OTHER OFFENSE  14634
# 6                           NARCOTICS  10907
# 7                            BURGLARY  10052
# 8                 MOTOR VEHICLE THEFT   8476
# 9                             ROBBERY   8291
# 10                  CRIMINAL TRESPASS   5993
# 11                  WEAPONS VIOLATION   4701
# 12         OFFENSE INVOLVING CHILDREN   1921
# 13                CRIM SEXUAL ASSAULT   1349
# 14             PUBLIC PEACE VIOLATION   1159
# 15   INTERFERENCE WITH PUBLIC OFFICER   1141
# 16                        SEX OFFENSE    930
# 17                       PROSTITUTION    621
# 18                           HOMICIDE    497
# 19                              ARSON    320
# ...

# %%
crimes_per_type = pd.DataFrame(data.groupby('Primary Type').size().sort_values(ascending=False).rename('Count').reset_index())

other_threshold = 5000

crimes_over_threshold = crimes_per_type[crimes_per_type['Count'] > other_threshold]
crimes_below_threshold = crimes_per_type[crimes_per_type['Count'] < other_threshold]

combined_crimes = crimes_over_threshold.append(pd.DataFrame(crimes_below_threshold.Count.sum(), index = ["Other"], columns=["Count"]))

combined_crimes.fillna(f"Other ({crimes_below_threshold['Primary Type'].size} types of crime)", inplace=True)

combined_crimes
# Out:
# C:\Users\Ian\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#        Count               Primary Type
# 0      55371                      THEFT
# 1      43319                    BATTERY
# 2      24102            CRIMINAL DAMAGE
# 3      17663                    ASSAULT
# 4      15377         DECEPTIVE PRACTICE
# 5      14634              OTHER OFFENSE
# 6      10907                  NARCOTICS
# 7      10052                   BURGLARY
# 8       8476        MOTOR VEHICLE THEFT
# 9       8291                    ROBBERY
# 10      5993          CRIMINAL TRESPASS
# Other  13787  Other (20 types of crime)

# %%
crimes_per_type = pd.DataFrame(data.groupby('Primary Type').size().sort_values(ascending=False).rename('Count').reset_index())

other_threshold = 5000

crimes_over_threshold = crimes_per_type[crimes_per_type['Count'] > other_threshold]
crimes_below_threshold = crimes_per_type[crimes_per_type['Count'] < other_threshold]

combined_crimes = crimes_over_threshold.append(pd.DataFrame(crimes_below_threshold.Count.sum(), index = ["Other"], columns=["Count"]))

combined_crimes.fillna(f"Other ({crimes_below_threshold['Primary Type'].size} types of crime)", inplace=True)

combined_crimes
# Out:
# C:\Users\Ian\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#        Count               Primary Type
# 0      55371                      THEFT
# 1      43319                    BATTERY
# 2      24102            CRIMINAL DAMAGE
# 3      17663                    ASSAULT
# 4      15377         DECEPTIVE PRACTICE
# 5      14634              OTHER OFFENSE
# 6      10907                  NARCOTICS
# 7      10052                   BURGLARY
# 8       8476        MOTOR VEHICLE THEFT
# 9       8291                    ROBBERY
# 10      5993          CRIMINAL TRESPASS
# Other  13787  Other (20 types of crime)

# %%
combined_crimes.plot(kind='bar', x='Primary Type', y='Count', figsize=(25,10))
plt.show()

# %%
#Crimes per date
#crimes_per_date = pd.DataFrame(data.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0101 = data[data['Date'].str.match('01/01/')]
crimes_per_date = pd.DataFrame(datum0101.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0101count = crimes_per_date.shape[0] #Anzahl der Straftaten am 01.01.

datum0201 = data[data['Date'].str.match('01/02/')]
crimes_per_date = pd.DataFrame(datum0201.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0201count = crimes_per_date.shape[0] #Anzahl der Straftaten am 02.01.

datum0301 = data[data['Date'].str.match('01/03/')]
crimes_per_date = pd.DataFrame(datum0301.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0301count = crimes_per_date.shape[0] #Anzahl der Straftaten am 03.01.

datum0401 = data[data['Date'].str.match('01/04/')]
crimes_per_date = pd.DataFrame(datum0401.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0401count = crimes_per_date.shape[0] #Anzahl der Straftaten am 04.01.

datum0501 = data[data['Date'].str.match('01/05/')]
crimes_per_date = pd.DataFrame(datum0501.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0501count = crimes_per_date.shape[0] #Anzahl der Straftaten am 05.01.

datum0601 = data[data['Date'].str.match('01/06/')]
crimes_per_date = pd.DataFrame(datum0601.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0601count = crimes_per_date.shape[0] #Anzahl der Straftaten am 06.01.

datum0701 = data[data['Date'].str.match('01/07/')]
crimes_per_date = pd.DataFrame(datum0701.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0701count = crimes_per_date.shape[0] #Anzahl der Straftaten am 07.01.

datum0801 = data[data['Date'].str.match('01/08/')]
crimes_per_date = pd.DataFrame(datum0801.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0801count = crimes_per_date.shape[0] #Anzahl der Straftaten am 08.01.

datum0901 = data[data['Date'].str.match('01/09/')]
crimes_per_date = pd.DataFrame(datum0901.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum0901count = crimes_per_date.shape[0] #Anzahl der Straftaten am 09.01.

datum1001 = data[data['Date'].str.match('01/10/')]
crimes_per_date = pd.DataFrame(datum1001.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1001count = crimes_per_date.shape[0] #Anzahl der Straftaten am 10.01.

datum1101 = data[data['Date'].str.match('01/11/')]
crimes_per_date = pd.DataFrame(datum1101.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1101count = crimes_per_date.shape[0] #Anzahl der Straftaten am 11.01.

datum1201 = data[data['Date'].str.match('01/12/')]
crimes_per_date = pd.DataFrame(datum1201.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1201count = crimes_per_date.shape[0] #Anzahl der Straftaten am 12.01.

datum1301 = data[data['Date'].str.match('01/13/')]
crimes_per_date = pd.DataFrame(datum1301.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1301count = crimes_per_date.shape[0] #Anzahl der Straftaten am 13.01.

datum1401 = data[data['Date'].str.match('01/14/')]
crimes_per_date = pd.DataFrame(datum1401.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1401count = crimes_per_date.shape[0] #Anzahl der Straftaten am 14.01.

datum1501 = data[data['Date'].str.match('01/15/')]
crimes_per_date = pd.DataFrame(datum1501.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1501count = crimes_per_date.shape[0] #Anzahl der Straftaten am 15.01.

datum1601 = data[data['Date'].str.match('01/16/')]
crimes_per_date = pd.DataFrame(datum1601.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1601count = crimes_per_date.shape[0] #Anzahl der Straftaten am 16.01.

datum1701 = data[data['Date'].str.match('01/17/')]
crimes_per_date = pd.DataFrame(datum1701.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1701count = crimes_per_date.shape[0] #Anzahl der Straftaten am 17.01.

datum1801 = data[data['Date'].str.match('01/18/')]
crimes_per_date = pd.DataFrame(datum1801.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1801count = crimes_per_date.shape[0] #Anzahl der Straftaten am 18.01.

datum1901 = data[data['Date'].str.match('01/19/')]
crimes_per_date = pd.DataFrame(datum1901.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum1901count = crimes_per_date.shape[0] #Anzahl der Straftaten am 19.01.

datum2001 = data[data['Date'].str.match('01/20/')]
crimes_per_date = pd.DataFrame(datum2001.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2001count = crimes_per_date.shape[0] #Anzahl der Straftaten am 20.01.

datum2101 = data[data['Date'].str.match('01/21/')]
crimes_per_date = pd.DataFrame(datum2101.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2101count = crimes_per_date.shape[0] #Anzahl der Straftaten am 21.01.

datum2201 = data[data['Date'].str.match('01/22/')]
crimes_per_date = pd.DataFrame(datum2201.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2201count = crimes_per_date.shape[0] #Anzahl der Straftaten am 22.01.

datum2301 = data[data['Date'].str.match('01/23/')]
crimes_per_date = pd.DataFrame(datum2301.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2301count = crimes_per_date.shape[0] #Anzahl der Straftaten am 23.01.

datum2401 = data[data['Date'].str.match('01/24/')]
crimes_per_date = pd.DataFrame(datum2401.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2401count = crimes_per_date.shape[0] #Anzahl der Straftaten am 24.01.

datum2501 = data[data['Date'].str.match('01/25/')]
crimes_per_date = pd.DataFrame(datum2501.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2501count = crimes_per_date.shape[0] #Anzahl der Straftaten am 25.01.

datum2601 = data[data['Date'].str.match('01/26/')]
crimes_per_date = pd.DataFrame(datum2601.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2601count = crimes_per_date.shape[0] #Anzahl der Straftaten am 26.01.

datum2701 = data[data['Date'].str.match('01/27/')]
crimes_per_date = pd.DataFrame(datum2701.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2701count = crimes_per_date.shape[0] #Anzahl der Straftaten am 27.01.

datum2801 = data[data['Date'].str.match('01/28/')]
crimes_per_date = pd.DataFrame(datum2801.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2801count = crimes_per_date.shape[0] #Anzahl der Straftaten am 28.01.

datum2901 = data[data['Date'].str.match('01/29/')]
crimes_per_date = pd.DataFrame(datum2901.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum2901count = crimes_per_date.shape[0] #Anzahl der Straftaten am 29.01.

datum3001 = data[data['Date'].str.match('01/30/')]
crimes_per_date = pd.DataFrame(datum3001.groupby('Date').size().sort_values(ascending=False).rename('Count').reset_index())
datum3001count = crimes_per_date.shape[0] #Anzahl der Straftaten am 30.01.

januar = {'Date': ['01.01.','02.01.','03.01.','04.01.','05.01.','06.01.', '07.01.', '08.01.','09.01.','10.01.','11.01.','12.01.','13.01.', '14.01.',
                     '15.01.', '16.01.', '17.01.', '18.01.', '19.01.', '20.01.', '21.01.', '22.01.', '23.01.', '24.01.', '25.01.', '26.01.', '27.01.', 
                     '28.01.', '29.01.', '30.01.', ], 
             'Count': [datum0101count, datum0201count, datum0301count, datum0401count, datum0501count, datum0601count, datum0701count, datum0801count, 
                       datum0901count, datum1001count, datum1101count, datum1201count, datum1301count, datum1401count, datum1501count, datum1601count,
                       datum1701count, datum1801count, datum1901count, datum2001count, datum2101count, datum2201count, datum2301count, datum2401count, 
                       datum2501count, datum2601count, datum2701count, datum2801count, datum2901count, datum3001count, ]}

januardf = pd.DataFrame(januar) #DataFrame erstellen

dfinverted = januardf[::-1] #invertieren, damit 01.01. oben steht (sieht aus wie Kalender)

dfinverted.plot(kind='barh', x='Date', y='Count', figsize=(15,9))
plt.show()
